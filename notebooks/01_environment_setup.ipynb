# %% [markdown]
# <a href="https://colab.research.google.com/github/ghazal-mohammad/ir-system/blob/main/notebooks/01_environment_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IR System — Environment Setup
# **Step 1:** Install libraries and verify datasets are accessible.

# %%
# Install all required libraries
# !pip install ir-datasets rank-bm25 sentence-transformers scikit-learn nltk spacy tqdm -q
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.1/866.1 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 34.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.5 MB/s eta 0:00:00
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Building wheel for cbor (setup.py) ... done

# %%
# Download NLTK data needed for preprocessing
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
print('NLTK data ready')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# NLTK data ready
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
import ir_datasets

# ---- Dataset 1: TREC Clinical Trials 2021 ----
print('Loading Dataset 1: trec-clinical-trials/2021 ...')
dataset1 = ir_datasets.load('trec-clinical-trials/2021')
print('Dataset 1 loaded successfully')
# Out:
# Loading Dataset 1: trec-clinical-trials/2021 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7374/4232978713.py in <cell line: 0>()
#       3 # ---- Dataset 1: TREC Clinical Trials 2021 ----
#       4 print('Loading Dataset 1: trec-clinical-trials/2021 ...')
# ----> 5 dataset1 = ir_datasets.load('trec-clinical-trials/2021')
#       6 print('Dataset 1 loaded successfully')
#
# /usr/local/lib/python3.12/dist-packages/ir_datasets/__init__.py in load(name)
#      20
#      21 def load(name):
# ---> 22     return registry[name]
#      23
#      24
#
# /usr/local/lib/python3.12/dist-packages/ir_datasets/util/registry.py in __getitem__(self, key)
#      23                     self.register(key, dataset)
#      24                     break
# ---> 25         result = self._registered[key]
#      26         if hasattr(result, 'deprecated'):
#      27             if os.environ.get('IR_DATASETS_SKIP_DEPRECATED_WARNING', '').lower() != 'true':
#
# KeyError: 'trec-clinical-trials/2021'

# %%
# Check Dataset 1 structure
print('=== Dataset 1: trec-clinical-trials/2021 ===')
print('Has docs:', dataset1.has_docs())
print('Has queries:', dataset1.has_queries())
print('Has qrels:', dataset1.has_qrels())

# Preview first document
for i, doc in enumerate(dataset1.docs_iter()):
    print('\n--- First Document ---')
    print('doc_id:', doc.doc_id)
    print('title:', doc.title[:100])
    print('condition:', str(doc.condition)[:100])
    break

# Preview first query
for i, query in enumerate(dataset1.queries_iter()):
    print('\n--- First Query ---')
    print('query_id:', query.query_id)
    print('text:', query.text)
    break

# Preview first qrel
for i, qrel in enumerate(dataset1.qrels_iter()):
    print('\n--- First Qrel ---')
    print('query_id:', qrel.query_id, '| doc_id:', qrel.doc_id, '| relevance:', qrel.relevance)
    break

# %%
# Count Dataset 1 stats
print('Counting docs (this takes a moment)...')
doc_count = sum(1 for _ in dataset1.docs_iter())
query_count = sum(1 for _ in dataset1.queries_iter())
qrel_count = sum(1 for _ in dataset1.qrels_iter())

print(f'Documents : {doc_count:,}')
print(f'Queries   : {query_count}')
print(f'Qrels     : {qrel_count:,}')

# %%
# ---- Dataset 2: MSMARCO Passage TREC DL 2019 ----
print('Loading Dataset 2: msmarco-passage/trec-dl-2019 ...')
dataset2 = ir_datasets.load('msmarco-passage/trec-dl-2019')
print('Dataset 2 loaded successfully')

# %%
# Check Dataset 2 structure
print('=== Dataset 2: msmarco-passage/trec-dl-2019 ===')
print('Has docs:', dataset2.has_docs())
print('Has queries:', dataset2.has_queries())
print('Has qrels:', dataset2.has_qrels())

# Preview first document
for i, doc in enumerate(dataset2.docs_iter()):
    print('\n--- First Document ---')
    print('doc_id:', doc.doc_id)
    print('text:', doc.text[:150])
    break

# Preview first query
for i, query in enumerate(dataset2.queries_iter()):
    print('\n--- First Query ---')
    print('query_id:', query.query_id)
    print('text:', query.text)
    break

# %%
# Unified data format — agreed structure for all services
# Every service must return results in this exact format:

RESULT_FORMAT = {
    'query_id': 'str',
    'results': [
        {
            'doc_id': 'str',
            'score': 'float',
            'rank': 'int'
        }
    ]
}

print('Data contract defined.')
print('All retrieval services must return this format.')
import json
print(json.dumps(RESULT_FORMAT, indent=2))

# %%
print('=== Environment Setup Complete ===')
print('Dataset 1 (Clinical Trials): Ready')
print('Dataset 2 (MSMARCO DL-2019): Ready')
print('Data format: Agreed')
print('Next: 02_preprocessing.ipynb')
